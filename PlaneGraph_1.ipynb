# %%
# %matplotlib inline
import numpy as np 
import matplotlib.pyplot as plt

x = np.linspace(-10,10,1000)

plt.plot(x, 2 * np.cos(x - np.pi/7)+3) 
plt.plot(x, 3 * np.cos(x - 2 * np.pi/5)-1)
plt.plot(x, 12/13 * np.cos(x - 4 * np.pi/11)+1)
